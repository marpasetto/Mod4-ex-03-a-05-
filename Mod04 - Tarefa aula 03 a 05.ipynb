# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
# 1) (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.

pc_mat = df_mat / 24
pc_por = df_por / 18
pc_geo = df_geo /  8
pc_ing = df_ing /  8
pc_his = df_his /  8
pc_fis = df_fis /  12
pc_qui = df_qui /  12

# %%
# 2) (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
total = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %%
# 3) Calcule o porcentual geral de cada aluno.
total/90
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %%
# 4) Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior ou igual que 45?

#total_corte_45.sum() ---> soma o valor total de acertos alunos


total_corte_45 = total[total['Qt_acertos'] >= 45]
total_corte_45.count() # --> soma a quantidade de alunos
# Out:
# Qt_acertos    34
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %%
# 1) Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. 
# Monte um novo DataFrame com os alunos desqualificados por este critério.

# fórmula: df_total[(dataframe['coluna'] bool)]

#Eliminados APENAS pelo critério de zerar as matérias matemática, física ou química (SEM CONSIDERAR NOTA DE CORTE > 45):

eliminados_materias = total[(df_mat['Qt_acertos'] == 0) |
                  (df_fis['Qt_acertos'] == 0) | (df_qui['Qt_acertos'] == 0)]

eliminados_materias
# Out:
#     Qt_acertos
# 3           32
# 6           29
# 10          31
# 12          42
# 14          31
# 20          53
# 25          27
# 26          40
# 27          50
# 33          39
# 35          48
# 49          19
# 56          39
# 65          24
# 66          31
# 72          50
# 73          37
# 74          39
# 84          26
# 89          63
# 92          40
# 94          25
# 98          40

# %%
# 2) Quantos são esses alunos? #Eliminados APENAS pelo critério 
#de zerar as matérias matemática, física ou química (SEM CONSIDERAR NOTA DE COR

eliminados_materias.count()
# Out:
# Qt_acertos    23
# dtype: int64

# %%
#3)Qual a média desses alunos em história?

media_his = eliminados_materias[(df_his['Qt_acertos'] > 0)]

media_his.mean()
# Out:
# C:\Users\Marina\AppData\Local\Temp\ipykernel_12556\3234627611.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   media_his = eliminados_materias[(df_his['Qt_acertos'] > 0)]
# Qt_acertos    37.904762
# dtype: float64

# %%
#3)Qual a média desses alunos em geografia?

media_geo = eliminados_materias[(df_geo['Qt_acertos'] > 0)]

media_geo.mean()
# Out:
# C:\Users\Marina\AppData\Local\Temp\ipykernel_12556\2243686257.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   media_geo = eliminados_materias[(df_geo['Qt_acertos'] > 0)]
# Qt_acertos    37.55
# dtype: float64

# %%
#4) Monte um DataFrame com os alunos que passaram para a segunda fase. 
# Repare que estes alunos não podem ter sido desqualificados


segunda_fase = total[(total['Qt_acertos'] >= 45) & (df_mat['Qt_acertos'] != 0) & 
                     (df_fis['Qt_acertos'] != 0) & (df_qui['Qt_acertos'] != 0)]

segunda_fase.count()
# Out:
# Qt_acertos    29
# dtype: int64

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?
#
#
# **OBS:** O portal do DATASUS pode apresentar instabilidades, retornando um erro na segunda célula abaixo. Por este motivo está disponível uma base estática, que se for baixada para o seu *working directory* pode ser lida com este comando: ```df = pd.read_csv('registros de vacinacao covid ACRE.csv', sep=';')```.
#
# **OBS2:** Para saber qual é o seu working directory, rode no jupyter: ```!pwd```.

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'

# %%
base = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-8de93c92-a256-421c-9d4c-c747c83096d4.c000.csv', sep=';')

display(base)
# Out:
# C:\Users\Marina\AppData\Local\Temp\ipykernel_12556\4249530338.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   base = pd.read_csv('https://s3.sa-east-1.amazonaws.com/ckan.saude.gov.br/SIPNI/COVID/uf/uf%3DAC/part-00000-8de93c92-a256-421c-9d4c-c747c83096d4.c000.csv', sep=';')
#                                       document_id  \
# 0       3bdcc124-6c78-47d0-9eb4-7cb47d10e27f-i0b0
# 1       e201d205-5de1-49a7-bdc0-18dfe264f3da-i0b0
# 2       51fd8c80-568f-4160-922b-11908935e19e-i0b0
# 3       e22f54c3-c669-4e7f-8865-4d8bb81755e0-i0b0
# 4       542d7458-8cb0-4804-a406-81fdad4e38e9-i0b0
# ...                                           ...
# 341752  c247b026-8f64-40c9-b278-2becd1e92e51-i0b0
# 341753  c26e6b14-5235-4b4e-8866-eefa6335477c-i0b0
# 341754  c27530d7-6c98-48f1-8a3d-97f5febb6ca9-i0b0
# 341755  c2e85edb-2597-492f-98d5-b0061d684e7e-i0b0
# 341756  c304770f-8f9a-4faa-a8ec-8cb996fe42ab-i0b0
#
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 341757 entries, 0 to 341756
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               341757 non-null  object
#  1   paciente_id                               341757 non-null  object
#  2   paciente_idade                            341757 non-null  int64
#  3   paciente_dataNascimento                   341757 non-null  object
#  4   paciente_enumSexoBiologico                341757 non-null  object
#  5   paciente_racaCor_codigo                   341757 non-null  int64
#  6   paciente_racaCor_valor                    341757 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         339672 non-null  object
#  8   paciente_endereco_coPais                  339676 non-null  object
#  9   paciente_endereco_nmMunicipio             339675 non-null  object
# ...

# %%
#excluindo nulos
base.dropna(inplace=True)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 285244 entries, 0 to 341756
# Data columns (total 32 columns):
#  #   Column                                    Non-Null Count   Dtype
# ---  ------                                    --------------   -----
#  0   document_id                               285244 non-null  object
#  1   paciente_id                               285244 non-null  object
#  2   paciente_idade                            285244 non-null  int64
#  3   paciente_dataNascimento                   285244 non-null  object
#  4   paciente_enumSexoBiologico                285244 non-null  object
#  5   paciente_racaCor_codigo                   285244 non-null  int64
#  6   paciente_racaCor_valor                    285244 non-null  object
#  7   paciente_endereco_coIbgeMunicipio         285244 non-null  object
#  8   paciente_endereco_coPais                  285244 non-null  object
#  9   paciente_endereco_nmMunicipio             285244 non-null  object
# ...

# %%
#1)Quantas vacinas estão registradas nessa base?
base['vacina_codigo'].nunique()
# Out:
# 9

# %%
#2)Quantos pacientes foram vacinados? (considere um paciente para cada valor único de paciente_id)

base['paciente_id'].nunique()
# Out:
# 240333

# %%
#3)Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. 
#Receba os valores do campo com o método .unique().

primeira_dose = base[(base['vacina_descricao_dose'] == '1ª Dose')]

primeira_dose['paciente_id'].nunique()
# Out:
# 107159

# %%
# 4) Quantos pacientes com menos de 18 anos foram vacinados?

menor_dezoito = base[(base['paciente_idade'] < 18)]

menor_dezoito['paciente_id'].count()
# Out:
# 33414

# %%
#5)Quantos estabelecimentos aplicaram vacina no Acre?

base['estabelecimento_razaoSocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
#1) crie uma cópia do DataFrame original, contendo somente os registros de vacinas realizadas a menores de 18 anos.

base_menores = base[(base['paciente_idade'] < 18)].copy()

base_menores
# Out:
#                                       document_id  \
# 13      e2bd790b-65e2-4de5-b3d6-830fd193b838-i0b0
# 27      e39a6ddd-5ff0-4293-8a48-c46571a563c9-i0b0
# 39      e477daa3-dbc9-44f6-94d3-b414104c76fd-i0b0
# 41      e596c48f-9b0f-4f42-90d3-d206ab288d32-i0b0
# 56      3693e557-c3ba-40f1-b13e-7fa9a98270f9-i0b0
# ...                                           ...
# 341663  b2dd904a-f1f1-4cb7-b855-df108ff4290d-i0b0
# 341676  b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 341688  b8654fa6-91a1-4954-ab73-2725c7578a19-i0b0
# 341704  bab13a03-7f78-4a23-93d4-9d99e80a8454-i0b0
# 341753  c26e6b14-5235-4b4e-8866-eefa6335477c-i0b0
#
#                                               paciente_id  paciente_idade  \
# 13      0db3e7a0bddca0a0bc7eacf4246412785835e63dbc541a...              13
# 27      529414de2720e5bceb22fe4b5335b8f637b18b9b0cbdd5...              17
# 39      dc585d3cb855d76caefe0207ee782b966eb737bd2f5e9b...              13
# ...

# %%
#2) crie uma lista das colunas desse DataFrame com o atributo de DataFrame .columns()
base_menores.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_dataNascimento', 'paciente_enumSexoBiologico',
#        'paciente_racaCor_codigo', 'paciente_racaCor_valor',
#        'paciente_endereco_coIbgeMunicipio', 'paciente_endereco_coPais',
#        'paciente_endereco_nmMunicipio', 'paciente_endereco_nmPais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumNacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoAtendimento_codigo',
#        'vacina_grupoAtendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataAplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
#        'sistema_origem'],
# ...

# %%
# 3)Nesse DataFrame faça uma contagem do campo vacina_categoria_nome. 
base_menores['vacina_categoria_nome'].value_counts()
# Out:
# Faixa Etária                                      28034
# Outros                                             3351
# Povos Indígenas                                    1544
# Povos e Comunidades Tradicionais                    394
# População Privada de Liberdade                       35
# Comorbidades                                         31
# Gestantes                                            14
# Trabalhadores de Saúde                                6
# Pessoas com Deficiência                               3
# Pessoas de 60 anos ou mais institucionalizadas        1
# Trabalhadores da Educação                             1
# Name: vacina_categoria_nome, dtype: int64

# %%
#4)a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento,
#faça uma lista com esses valores
lista_estabelecimentos = ['estabelecimento_valor',
       'estabelecimento_razaoSocial', 'estalecimento_noFantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']

menor_lista = base_menores.loc[:,lista_estabelecimentos]

menor_lista.shape
# Out:
# (33414, 6)

# %%
#5) Aplique o método .drop_duplicates e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento
df = menor_lista.drop_duplicates()
df
# Out:
#         estabelecimento_valor              estabelecimento_razaoSocial  \
# 13                    6917291       PREFEITURA MUNICIPAL DE RIO BRANCO
# 39                    2001039         PREFEITURA MUNICIPAL DE CAPIXABA
# 79                    2001454        PREFEITURA MUNICIPAL DE BRASILEIA
# 89                    2002914  PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 112                   3810771         PREFEITURA MUNICIPAL DE TARAUACA
# ...                       ...                                      ...
# 81943                 2000091      PREFEITURA MUNICIPAL DE MANCIO LIMA
# 108793                3042553        PREFEITURA MUNICIPAL DE BRASILEIA
# 150761                2000881   PREFEITURA MUNICIPAL DE SENA MADUREIRA
# 164664                7123043           PREFEITURA MUNICIPAL DE JORDAO
# 259769                7617852             PREFEITURA DE SENA MADUREIRA
#
#                                  estalecimento_noFantasia  \
# ...
